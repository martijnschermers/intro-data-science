# %% [markdown]
# ### Portfolio assignment 6
# 60 min:
# Perform a univariate analysis on:
# - 2 columns with categorical data
# - 2 columns with numerical data
#
# Commit the Notebook to your portfolio when you're finished.

# %%
import pandas as pd

# %%
vehicles = pd.read_csv('../datasets/vehicles.csv', sep=',')

# %%
vehicles.describe()
# Out:
#                  id         price          year      odometer  county  \
# count  5.694100e+04  5.694100e+04  56699.000000  5.592400e+04     0.0
# mean   7.312298e+09  1.288718e+05   2011.122507  9.615441e+04     NaN
# std    4.717742e+06  1.482308e+07     10.287328  2.656589e+05     NaN
# min    7.208550e+09  0.000000e+00   1900.000000  0.000000e+00     NaN
# 25%    7.309813e+09  5.995000e+03   2008.000000  3.502900e+04     NaN
# 50%    7.313962e+09  1.404900e+04   2014.000000  7.941700e+04     NaN
# 75%    7.315803e+09  2.659000e+04   2017.000000  1.265000e+05     NaN
# max    7.316925e+09  3.009549e+09   2022.000000  1.000000e+07     NaN
#
#                 lat          long
# count  56789.000000  56789.000000
# mean      37.030119   -114.288149
# std        6.773016     14.966395
# min      -81.838232   -158.599600
# 25%       33.741517   -121.217308
# 50%       34.653081   -117.826758
# 75%       38.556800   -111.666438
# max       82.390818    173.885502

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56941 entries, 0 to 56940
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            56941 non-null  int64
#  1   url           56941 non-null  object
#  2   region        56941 non-null  object
#  3   region_url    56941 non-null  object
#  4   price         56941 non-null  int64
#  5   year          56699 non-null  float64
#  6   manufacturer  54509 non-null  object
#  7   model         56127 non-null  object
#  8   condition     34824 non-null  object
#  9   cylinders     34226 non-null  object
#  10  fuel          56720 non-null  object
#  11  odometer      55924 non-null  float64
#  12  title_status  55717 non-null  object
#  13  transmission  56713 non-null  object
#  14  VIN           35852 non-null  object
#  15  drive         39211 non-null  object
#  16  size          15137 non-null  object
#  17  type          44854 non-null  object
# ...

# %%
# Univariate analyse op 'manufacturer' colom (categorisch)

vehicles['manufacturer'].value_counts()
# Out:
# ford               8795
# chevrolet          7126
# toyota             5381
# honda              2916
# nissan             2859
# ram                2302
# bmw                2132
# jeep               2116
# mercedes-benz      2036
# gmc                1968
# dodge              1752
# hyundai            1500
# volkswagen         1473
# kia                1334
# lexus              1293
# subaru             1109
# audi                931
# cadillac            820
# acura               808
# mazda               713
# chrysler            671
# infiniti            626
# buick               516
# lincoln             446
# volvo               440
# mini                400
# mitsubishi          385
# rover               308
# porsche             246
# jaguar              237
# pontiac             182
# fiat                176
# alfa-romeo          137
# tesla               130
# saturn               94
# mercury              94
# harley-davidson      23
# ferrari              19
# ...

# %%
vehicles['manufacturer'].describe()
# Out:
# count     54509
# unique       41
# top        ford
# freq       8795
# Name: manufacturer, dtype: object

# %%
vehicles['manufacturer'].value_counts().plot(kind='bar', title='Amount of cars per Brand', ylabel='Amount', xlabel='Brand')
# Out:
# <AxesSubplot:title={'center':'Amount of cars per Brand'}, xlabel='Brand', ylabel='Amount'>

# %%
# Univariate analyse op 'condition' colom (categorisch)

vehicles['condition'].value_counts()
# Out:
# excellent    15588
# good         14789
# like new      3325
# fair           881
# new            133
# salvage        108
# Name: condition, dtype: int64

# %%
vehicles['condition'].describe()
# Out:
# count         34824
# unique            6
# top       excellent
# freq          15588
# Name: condition, dtype: object

# %%
vehicles['condition'].value_counts().plot(kind='line', title='Amount of cars per Condition', ylabel='Amount', xlabel='Condition')
# Out:
# <AxesSubplot:title={'center':'Amount of cars per Condition'}, xlabel='Condition', ylabel='Amount'>

# %%
vehicles['condition'].value_counts().plot(kind='bar', title='Amount of cars per Condition', ylabel='Amount', xlabel='Condition')
# Out:
# <AxesSubplot:title={'center':'Amount of cars per Condition'}, xlabel='Condition', ylabel='Amount'>

# %%
# Univariate analyse op 'year' colom (numeriek)

vehicles['year'].describe()
# Out:
# count    56699.000000
# mean      2011.122507
# std         10.287328
# min       1900.000000
# 25%       2008.000000
# 50%       2014.000000
# 75%       2017.000000
# max       2022.000000
# Name: year, dtype: float64

# %%
# Univariate analyse op 'price' colom (numeriek)

vehicles['price'].describe()
# Out:
# count    5.694100e+04
# mean     1.288718e+05
# std      1.482308e+07
# min      0.000000e+00
# 25%      5.995000e+03
# 50%      1.404900e+04
# 75%      2.659000e+04
# max      3.009549e+09
# Name: price, dtype: float64
